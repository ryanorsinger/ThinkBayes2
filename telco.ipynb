# %%
import pandas as pd

# %%
filename = "telco.csv"
df = pd.read_csv(filename)
# df = pd.read_csv(filename, index_col="customer_id")
df = df.drop(columns=["Unnamed: 0", "payment_type_id", "internet_service_type_id", "contract_type_id"])

# %%
df
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines online_security online_backup  ...  \
# 0              Yes                No              No           Yes  ...
# ...

# %%
churned = df.churn == "Yes"

# %%
female = df.gender == "Female"
male = df.gender == "Male"

# %%
pd.DataFrame(df.groupby("gender").churn.value_counts(normalize=True))
# Out:
#                  churn
# gender churn
# Female No     0.730791
#        Yes    0.269209
# Male   No     0.738397
#        Yes    0.261603

# %%
pd.DataFrame(df.groupby("churn").gender.value_counts(normalize=True))
# Out:
#                 gender
# churn gender
# No    Male    0.507344
#       Female  0.492656
# Yes   Female  0.502408
#       Male    0.497592

# %%
pd.DataFrame(df.groupby(["churn", "gender"]).senifor_citizen.value_counts(normalize=True))
# Out:
#                              senior_citizen
# churn gender senior_citizen
# No    Female 0                     0.871322
#              1                     0.128678
#       Male   0                     0.871238
#              1                     0.128762
# Yes   Female 0                     0.744409
#              1                     0.255591
#       Male   0                     0.746237
#              1                     0.253763

# %%
# Probability function 
def prob(A):
    """Accepts a series/array of booleans and returns the proportion of population that matches"""
    return A.mean()

# %%
def conditional(proposition, given):
    """Probability of A conditioned on given."""
    return prob(proposition[given])

# %%
conditional(churned, given=male)
# Out:
# 0.2616033755274262

# %%
conditional(churned, given=female)
# Out:
# 0.26920871559633025
